# %% [markdown]
# # Recursive Self-Improvement Prompting
# "Recursive Self-Improvement (RSI) iteratively refines the AI’s output by having it review, critique, and enhance its own response until an optimized version is achieved."

# %%
##
## RECURSIVE SELF-IMPROVEMENT PROMPTING
##

from _pipeline import create_payload, model_req

#### (1) Level 1 - Initial Requirement Analysis Generation
LEVEL_1_PROMPT = """You are an AI Software Requirements Analyst. Generate a structured requirement analysis for **NeuraBot, an AI-powered Study Companion**.

## **Step 1: Initial Draft**
Generate a structured list of **Functional and Non-Functional Requirements** for NeuraBot.

### **1. Functional Requirements (Exactly 2 Unique Features)**
- List **exactly 2 distinct chatbot features** related to **study assistance, tutoring, or student engagement**.

### **2. Non-Functional Requirements (Exactly 2 Key Aspects)**
- **Security**: Describe **data encryption and user authentication**.
- **Scalability**: Explain how the system efficiently **handles multiple users**.

### **3. Completion Rules**
- **Do not stop early**; fully complete all sections.
- **No additional sections beyond Functional & Non-Functional Requirements**.
- **Do not include assumptions, summaries, or explanations**.

Use **structured bullet points**."""

#### (2) Configure Model Request - Initial Run
payload_1 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_1_PROMPT, 
                           temperature=0.7,  
                           num_ctx=512,  
                           num_predict=600)  

### SEND FIRST REQUEST (Level 1 - Initial Draft)
time_1, response_1 = model_req(payload=payload_1)
print("Initial Draft Response:\n", response_1)
print(f"Time taken: {time_1}s")

#### (3) Level 2 - Self-Review and Improvement
LEVEL_2_PROMPT = f"""You previously generated a structured requirement analysis. Now, **critique and improve your own response**.

## **Step 2: Self-Review & Enhancement**
- Identify **any vague, redundant, or missing details**.
- Improve **clarity, precision, and technical accuracy**.
- Ensure **concise but fully detailed descriptions**.

### **Previous Response:**
{response_1}

### **Now, revise your response to address identified issues and enhance quality.**
- **Strictly maintain 2 Functional & 2 Non-Functional Requirements**.
- **Ensure technical depth without unnecessary verbosity**.
- **Do not generate additional sections or summaries**."""

#### (4) Configure Model Request - Self-Improvement Step
payload_2 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_2_PROMPT, 
                           temperature=0.6,  
                           num_ctx=512,  
                           num_predict=500)  

### SEND SECOND REQUEST (Level 2 - Self-Improvement)
time_2, response_2 = model_req(payload=payload_2)
print("\nRefined Response (Self-Improved):\n", response_2)
print(f"Time taken: {time_2}s")

#### (5) Level 3 - Final Optimization for Clarity & Conciseness
LEVEL_3_PROMPT = f"""You have improved the structured requirement analysis. Now, perform **a final optimization pass**.

## **Step 3: Final Optimization**
- Ensure **concise but complete descriptions**.
- Remove **any redundant words or unnecessary complexity**.
- Maintain **structured bullet points**.

### **Previous Self-Improved Response:**
{response_2}

### **Now, generate the final optimized structured requirement analysis.**
- **Ensure all sections are fully completed**.
- **No extra comments or concluding remarks**."""

#### (6) Configure Model Request - Final Optimization
payload_3 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_3_PROMPT, 
                           temperature=0.5,  
                           num_ctx=512,  
                           num_predict=400)  

### SEND THIRD REQUEST (Level 3 - Final Optimization)
time_3, response_3 = model_req(payload=payload_3)
print("\nFinal Optimized Response:\n", response_3)
print(f"Time taken: {time_3}s")
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'You are an AI Software Requirements Analyst. Generate a structured requirement analysis for **NeuraBot, an AI-powered Study Companion**.\n\n## **Step 1: Initial Draft**\nGenerate a structured list of **Functional and Non-Functional Requirements** for NeuraBot.\n\n### **1. Functional Requirements (Exactly 2 Unique Features)**\n- List **exactly 2 distinct chatbot features** related to **study assistance, tutoring, or student engagement**.\n\n### **2. Non-Functional Requirements (Exactly 2 Key Aspects)**\n- **Security**: Describe **data encryption and user authentication**.\n- **Scalability**: Explain how the system efficiently **handles multiple users**.\n\n### **3. Completion Rules**\n- **Do not stop early**; fully complete all sections.\n- **No additional sections beyond Functional & Non-Functional Requirements**.\n- **Do not include assumptions, summaries, or explanations**.\n\nUse **structured bullet points**.', 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 512, 'num_predict': 600}}
# Initial Draft Response:
#  **NeuraBot: AI-powered Study Companion**
#
# **Step 1: Initial Draft**
#
# ### **1. Functional Requirements (Exactly 2 Unique Features)**
#
# * Feature 1: **Personalized Learning Path**
# 	+ The system should be able to create a customized learning plan for each user based on their strengths, weaknesses, and learning style.
# 	+ The plan should include relevant topics, exercises, and resources tailored to the individual's needs.
# * Feature 2: **Real-time Tutoring Sessions**
# 	+ The system should enable live tutoring sessions between users and certified tutors via video conferencing or messaging.
# 	+ Tutors should be able to track user progress, provide feedback, and adjust their teaching approach accordingly.
#
# ### **2. Non-Functional Requirements (Exactly 2 Key Aspects)**
#
# * **Security**:
# 	+ Data encryption: All user data, including personal identifiable information, study materials, and communication logs, should be encrypted using industry-standard protocols.
# 	+ User authentication: The system should implement a secure login mechanism with multi-factor authentication to prevent unauthorized access.
# * **Scalability**:
# 	+ The system should be able to handle an increasing number of users without compromising performance or response time.
# 	+ The infrastructure should be designed to scale horizontally, allowing for easy addition of new servers or nodes as the user base grows.
#
# ### **3. Completion Rules**
#
# No additional sections beyond Functional & Non-Functional Requirements will be included.
# Time taken: 60.398s
# {'model': 'llama3.2:latest', 'prompt': "You previously generated a structured requirement analysis. Now, **critique and improve your own response**.\n\n## **Step 2: Self-Review & Enhancement**\n- Identify **any vague, redundant, or missing details**.\n- Improve **clarity, precision, and technical accuracy**.\n- Ensure **concise but fully detailed descriptions**.\n\n### **Previous Response:**\n**NeuraBot: AI-powered Study Companion**\n\n**Step 1: Initial Draft**\n\n### **1. Functional Requirements (Exactly 2 Unique Features)**\n\n* Feature 1: **Personalized Learning Path**\n\t+ The system should be able to create a customized learning plan for each user based on their strengths, weaknesses, and learning style.\n\t+ The plan should include relevant topics, exercises, and resources tailored to the individual's needs.\n* Feature 2: **Real-time Tutoring Sessions**\n\t+ The system should enable live tutoring sessions between users and certified tutors via video conferencing or messaging.\n\t+ Tutors should be able to track user progress, provide feedback, and adjust their teaching approach accordingly.\n\n### **2. Non-Functional Requirements (Exactly 2 Key Aspects)**\n\n* **Security**:\n\t+ Data encryption: All user data, including personal identifiable information, study materials, and communication logs, should be encrypted using industry-standard protocols.\n\t+ User authentication: The system should implement a secure login mechanism with multi-factor authentication to prevent unauthorized access.\n* **Scalability**:\n\t+ The system should be able to handle an increasing number of users without compromising performance or response time.\n\t+ The infrastructure should be designed to scale horizontally, allowing for easy addition of new servers or nodes as the user base grows.\n\n### **3. Completion Rules**\n\nNo additional sections beyond Functional & Non-Functional Requirements will be included.\n\n### **Now, revise your response to address identified issues and enhance quality.**\n- **Strictly maintain 2 Functional & 2 Non-Functional Requirements**.\n- **Ensure technical depth without unnecessary verbosity**.\n- **Do not generate additional sections or summaries**.", 'stream': False, 'options': {'temperature': 0.6, 'num_ctx': 512, 'num_predict': 500}}
#
# Refined Response (Self-Improved):
#  ## Enhanced Response: Structured Requirement Analysis for NeuraBot
#
# ### Step 1: Initial Draft
#
# NeuraBot is an AI-powered study companion designed to provide personalized learning experiences for users.
#
# ### Step 2: Functional Requirements (Exactly 2 Unique Features)
#
# #### Feature 1: Adaptive Learning Engine
# The adaptive learning engine will utilize machine learning algorithms to analyze user performance, identify knowledge gaps, and adjust the difficulty level of study materials in real-time. This feature will ensure that users receive a tailored learning experience, promoting engagement and maximizing learning outcomes.
#
# #### Feature 2: Intelligent Assistant for Task Management
# The intelligent assistant will provide users with personalized task management recommendations, including suggested schedules, reminders, and progress tracking. This feature will help users stay organized, focused, and motivated throughout their studies.
#
# ### Step 3: Non-Functional Requirements (Exactly 2)
#
# #### Security
# All user data will be encrypted using industry-standard protocols (e.g., AES-256) to ensure confidentiality and integrity. The system will implement a secure login mechanism with multi-factor authentication (MFA) to prevent unauthorized access, including:
#
# * Password hashing and salting
# * Token-based authentication
# * SMS/phone number verification
#
# #### Scalability
# The NeuraBot platform will be designed to scale horizontally, allowing for easy addition of new servers or nodes as the user base grows. This will ensure that the system can handle increased traffic, user data storage, and computational demands without compromising performance or response time.
#
# ### Completion
# Time taken: 64.837s
# {'model': 'llama3.2:latest', 'prompt': 'You have improved the structured requirement analysis. Now, perform **a final optimization pass**.\n\n## **Step 3: Final Optimization**\n- Ensure **concise but complete descriptions**.\n- Remove **any redundant words or unnecessary complexity**.\n- Maintain **structured bullet points**.\n\n### **Previous Self-Improved Response:**\n## Enhanced Response: Structured Requirement Analysis for NeuraBot\n\n### Step 1: Initial Draft\n\nNeuraBot is an AI-powered study companion designed to provide personalized learning experiences for users.\n\n### Step 2: Functional Requirements (Exactly 2 Unique Features)\n\n#### Feature 1: Adaptive Learning Engine\nThe adaptive learning engine will utilize machine learning algorithms to analyze user performance, identify knowledge gaps, and adjust the difficulty level of study materials in real-time. This feature will ensure that users receive a tailored learning experience, promoting engagement and maximizing learning outcomes.\n\n#### Feature 2: Intelligent Assistant for Task Management\nThe intelligent assistant will provide users with personalized task management recommendations, including suggested schedules, reminders, and progress tracking. This feature will help users stay organized, focused, and motivated throughout their studies.\n\n### Step 3: Non-Functional Requirements (Exactly 2)\n\n#### Security\nAll user data will be encrypted using industry-standard protocols (e.g., AES-256) to ensure confidentiality and integrity. The system will implement a secure login mechanism with multi-factor authentication (MFA) to prevent unauthorized access, including:\n\n* Password hashing and salting\n* Token-based authentication\n* SMS/phone number verification\n\n#### Scalability\nThe NeuraBot platform will be designed to scale horizontally, allowing for easy addition of new servers or nodes as the user base grows. This will ensure that the system can handle increased traffic, user data storage, and computational demands without compromising performance or response time.\n\n### Completion\n\n### **Now, generate the final optimized structured requirement analysis.**\n- **Ensure all sections are fully completed**.\n- **No extra comments or concluding remarks**.', 'stream': False, 'options': {'temperature': 0.5, 'num_ctx': 512, 'num_predict': 400}}
#
# Final Optimized Response:
#  ## Enhanced Response: Structured Requirement Analysis for NeuraBot
#
# ### Step 1: Initial Draft
# NeuraBot is an AI-powered study companion designed to provide personalized learning experiences for users.
#
# ### Step 2: Functional Requirements (Exactly 2 Unique Features)
#
# #### **Feature 1: Adaptive Learning Engine**
# Utilize machine learning algorithms to analyze user performance, identify knowledge gaps, and adjust difficulty level of study materials in real-time.
#
# * Analyze user data to create a customized learning plan
# * Provide real-time feedback and assessment
# * Continuously update content based on user progress
#
# #### **Feature 2: Virtual Learning Assistant**
# Offer interactive support through various channels (text, voice, or video).
#
# * Integrate natural language processing (NLP) for effective conversation management
# * Implement knowledge base to provide accurate information on a wide range of topics
#
# ### Step 3: Non-Functional Requirements
#
# #### **Security**
#
# * Encrypt user data using industry-standard protocols (e.g., AES-256)
# * Implement secure login mechanism with multi-factor authentication (MFA)
#
# * Password hashing and salting
# * Token-based authentication
# * SMS/phone number verification
#
# #### **Scalability**
#
# * Design platform to scale horizontally, adding new servers or nodes as user base grows
# * Ensure system can handle increased traffic, user data storage, and computational demands without compromising performance or response time
#
# ### Step 4: Acceptance Criteria
# Time taken: 79.075s

# %% [markdown]
# # Issues Identified
# 1)Over-Generated Functional & Non-Functional Requirements → AI listed too many features (beyond 2 each).
# 2)Included Extra "Additional Requirements" → Violates instructions to limit output to Functional & Non-Functional only.
# 3)Too Much Generalization → Features like "Integration with LMS, CRM, or External Systems" are too broad.
# 4)Time Taken (60.053s) is Slightly Long → AI could refine faster.
