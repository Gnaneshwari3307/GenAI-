# %% [markdown]
# # Hierarchical Prompt
# "Hierarchical PromptChaining breaks down the prompt into multiple refinement levels, ensuring progressively improved and structured outputs."

# %%
##
## HIERARCHICAL PROMPT CHAINING (FINAL REFINEMENT & TRUNCATION FIX)
##

from _pipeline import create_payload, model_req

#### (1) Level 1 - Initial Prompt: Generate a Basic Requirement Analysis
LEVEL_1_PROMPT = """You are an AI Software Requirements Analyst. Your task is to generate a structured requirement analysis for **NeuraBot, an AI-powered Study Companion**.

## **Step 1: Initial Draft**
Generate a rough draft of **Functional and Non-Functional Requirements** for NeuraBot.

### **1. Functional Requirements (2 Unique Features)**
- List **exactly 2 distinct chatbot features** related to **study assistance, tutoring, or student engagement**.

### **2. Non-Functional Requirements (2 Key Aspects)**
- **Security**: Describe **data encryption and user authentication**.
- **Scalability**: Explain how the system efficiently **handles multiple users**.

### **3. Rules for Completion**
- **Do not stop early**; complete all sections fully.
- **No unnecessary comments, explanations, or conclusions**.

Use **structured bullet points**."""

#### (2) Configure the Model request, simulating Workflow Orchestration
payload_1 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_1_PROMPT, 
                           temperature=0.8,  
                           num_ctx=512,  
                           num_predict=1000)  # Increased prediction to prevent truncation

### SEND FIRST REQUEST (Level 1 - Initial Draft)
time_1, response_1 = model_req(payload=payload_1)
print("Initial Draft Response:\n", response_1)
print(f"Time taken: {time_1}s")

#### (3) Level 2 - Refinement: Improve Specificity and Structure
LEVEL_2_PROMPT = f"""Your previous draft provided a general overview. Now, refine and enhance it.

## **Step 2: Refinement**
- **Functional Requirements**: Ensure **precise AI-driven study assistant functionalities** (not generic chatbot features).
- **Non-Functional Requirements**: Make **Security & Scalability** concise but impactful.

### **Previous Response:**
{response_1}

### **Now, refine the structured requirement analysis to be more precise, technical, and structured.**
- **Complete all sections without stopping early**.
- **No unnecessary comments or conclusions**."""

#### (4) Configure the Model request, simulating Workflow Orchestration for Refinement
payload_2 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_2_PROMPT, 
                           temperature=0.7,  
                           num_ctx=512,  
                           num_predict=800)  

### SEND SECOND REQUEST (Level 2 - Refinement)
time_2, response_2 = model_req(payload=payload_2)
print("\nRefined Response:\n", response_2)
print(f"Time taken: {time_2}s")

#### (5) Level 3 - Final Optimization: Ensure Clarity and Conciseness
LEVEL_3_PROMPT = f"""Your last response improved the requirements, but now optimize for clarity.

## **Step 3: Final Optimization**
- Ensure **concise but complete** descriptions.
- **Remove redundant words** while keeping **technical depth**.
- Maintain **structured bullet points**.
- **Do not include unnecessary explanations or conclusions**.

### **Previous Refined Response:**
{response_2}

### **Now, generate the final optimized structured requirement analysis.**
- **Ensure all sections are fully completed**.
- **No extra comments or "basic outline" statements**."""

#### (6) Configure the Model request, simulating Workflow Orchestration for Final Optimization
payload_3 = create_payload(target="ollama",
                           model="llama3.2:latest", 
                           prompt=LEVEL_3_PROMPT, 
                           temperature=0.6,  
                           num_ctx=512,  
                           num_predict=700)  

### SEND THIRD REQUEST (Level 3 - Final Optimization)
time_3, response_3 = model_req(payload=payload_3)
print("\nFinal Optimized Response:\n", response_3)
print(f"Time taken: {time_3}s")
# Out:
# {'model': 'llama3.2:latest', 'prompt': 'You are an AI Software Requirements Analyst. Your task is to generate a structured requirement analysis for **NeuraBot, an AI-powered Study Companion**.\n\n## **Step 1: Initial Draft**\nGenerate a rough draft of **Functional and Non-Functional Requirements** for NeuraBot.\n\n### **1. Functional Requirements (2 Unique Features)**\n- List **exactly 2 distinct chatbot features** related to **study assistance, tutoring, or student engagement**.\n\n### **2. Non-Functional Requirements (2 Key Aspects)**\n- **Security**: Describe **data encryption and user authentication**.\n- **Scalability**: Explain how the system efficiently **handles multiple users**.\n\n### **3. Rules for Completion**\n- **Do not stop early**; complete all sections fully.\n- **No unnecessary comments, explanations, or conclusions**.\n\nUse **structured bullet points**.', 'stream': False, 'options': {'temperature': 0.8, 'num_ctx': 512, 'num_predict': 1000}}
# Initial Draft Response:
#  Here is a structured requirement analysis for NeuraBot, an AI-powered Study Companion:
#
# ## Step 1: Initial Draft
#
# ### Functional Requirements (2 Unique Features)
#
# * **Feature 1:** **Personalized Study Plan Generation**
# 	+ The system will generate customized study plans based on individual user goals, learning style, and pace.
# 	+ The plan will include a schedule of topics to be covered, with relevant resources and practice questions.
# 	+ The feature will adapt to the user's progress, adjusting the difficulty level and content as needed.
# * **Feature 2:** **Intelligent Tutoring System**
# 	+ The system will employ AI-powered tutoring that provides real-time guidance and feedback on student performance.
# 	+ The tutor will offer explanations, examples, and practice problems tailored to the individual's needs.
# 	+ The feature will continuously assess the user's understanding and adjust its responses accordingly.
#
# ### Non-Functional Requirements (2 Key Aspects)
#
# * **Security**:
# 	+ All user data will be encrypted using AES-256 encryption protocol.
# 	+ User authentication will be handled through a secure username/password combination, with optional biometric login options for added security.
# 	+ Regular security audits and penetration testing will be performed to ensure the system's vulnerability is minimized.
# * **Scalability**:
# 	+ The system will be designed to handle an increasing number of users without compromising performance or response time.
# 	+ The architecture will utilize a load balancer to distribute user traffic across multiple servers, ensuring efficient resource allocation and minimizing downtime.
# 	+ Continuous monitoring and evaluation of the system's performance will identify bottlenecks and optimize resources for optimal scalability.
#
# ### Additional Requirements
#
# * User-friendly interface with intuitive navigation
# * Mobile-responsive design for seamless experience across devices
# * Integration with popular learning management systems (LMS)
# * Regular software updates and maintenance to ensure compatibility and security
#
# This system will provide an engaging, personalized learning experience that caters to diverse user needs, promoting academic success and lifelong learning.
# Time taken: 58.537s
# {'model': 'llama3.2:latest', 'prompt': "Your previous draft provided a general overview. Now, refine and enhance it.\n\n## **Step 2: Refinement**\n- **Functional Requirements**: Ensure **precise AI-driven study assistant functionalities** (not generic chatbot features).\n- **Non-Functional Requirements**: Make **Security & Scalability** concise but impactful.\n\n### **Previous Response:**\nHere is a structured requirement analysis for NeuraBot, an AI-powered Study Companion:\n\n## Step 1: Initial Draft\n\n### Functional Requirements (2 Unique Features)\n\n* **Feature 1:** **Personalized Study Plan Generation**\n\t+ The system will generate customized study plans based on individual user goals, learning style, and pace.\n\t+ The plan will include a schedule of topics to be covered, with relevant resources and practice questions.\n\t+ The feature will adapt to the user's progress, adjusting the difficulty level and content as needed.\n* **Feature 2:** **Intelligent Tutoring System**\n\t+ The system will employ AI-powered tutoring that provides real-time guidance and feedback on student performance.\n\t+ The tutor will offer explanations, examples, and practice problems tailored to the individual's needs.\n\t+ The feature will continuously assess the user's understanding and adjust its responses accordingly.\n\n### Non-Functional Requirements (2 Key Aspects)\n\n* **Security**:\n\t+ All user data will be encrypted using AES-256 encryption protocol.\n\t+ User authentication will be handled through a secure username/password combination, with optional biometric login options for added security.\n\t+ Regular security audits and penetration testing will be performed to ensure the system's vulnerability is minimized.\n* **Scalability**:\n\t+ The system will be designed to handle an increasing number of users without compromising performance or response time.\n\t+ The architecture will utilize a load balancer to distribute user traffic across multiple servers, ensuring efficient resource allocation and minimizing downtime.\n\t+ Continuous monitoring and evaluation of the system's performance will identify bottlenecks and optimize resources for optimal scalability.\n\n### Additional Requirements\n\n* User-friendly interface with intuitive navigation\n* Mobile-responsive design for seamless experience across devices\n* Integration with popular learning management systems (LMS)\n* Regular software updates and maintenance to ensure compatibility and security\n\nThis system will provide an engaging, personalized learning experience that caters to diverse user needs, promoting academic success and lifelong learning.\n\n### **Now, refine the structured requirement analysis to be more precise, technical, and structured.**\n- **Complete all sections without stopping early**.\n- **No unnecessary comments or conclusions**.", 'stream': False, 'options': {'temperature': 0.7, 'num_ctx': 512, 'num_predict': 800}}
#
# Refined Response:
#  ## Structured Requirement Analysis for Personalized Learning System
#
# ### Overview
# The following is a comprehensive requirement analysis for the development of a personalized learning system designed to cater to diverse user needs, promoting academic success and lifelong learning.
#
# ### 1. Functional Requirements
#
# #### 1.1 User Registration and Login
# * Users will be able to register with their username, email address, and password.
# * The system will ensure that each user has a unique username and email address, preventing duplicate accounts.
# * Users can log in using their credentials or opt for biometric login options (optional).
#
# #### 1.2 Course Management
# * Users will have access to a comprehensive catalog of courses, including descriptions, prerequisites, and course materials.
# * The system will display relevant course suggestions based on user interests and skill levels.
#
# #### 1.3 Learning Paths
# * Users can create personalized learning paths tailored to their goals, interests, and skills.
# * Each learning path will include a list of recommended courses, readings, and assignments.
#
# #### 1.4 Adaptive Assessment
# * The system will conduct regular assessments to evaluate user progress and understanding.
# * Assessments will be adaptive, adjusting difficulty levels based on user performance.
#
# #### 1.5 Personalized Feedback
# * Users will receive personalized feedback on their performance, including explanations of correct answers and suggested improvements.
# * Feedback will be provided in a clear, concise manner, ensuring users understand the material.
#
# ### 2. Non-Functional Requirements
#
# #### 2.1 Performance
# * The system must respond to user interactions within 2 seconds.
# * Average page load time should be less than 3 seconds.
#
# #### 2.2 Security
# * User data will be encrypted using industry-standard encryption protocols (e.g., AES).
# * Passwords will be hashed and stored securely, requiring users to change passwords every 90 days.
#
# #### 2.3 Usability
# * The system must be accessible on a range of devices, including desktops, laptops, tablets, and mobile phones.
# * Navigation should be intuitive, with clear typography and color schemes that reduce visual stress.
#
# ### 3. Technical Requirements
#
# #### 3.1 Frontend Framework
# * Utilize a popular frontend framework (e.g., React, Angular) to ensure responsiveness and maintainability.
# * Ensure compatibility across various browsers and devices.
#
# #### 3.2 Backend Platform
# * Choose a robust backend platform (e.g., Node.js, Django) that supports scalability and high traffic.
# * Integrate with cloud services for storage and analytics.
#
# #### 3.3 Database Management
# * Select a reliable database management system (e.g., MySQL, PostgreSQL) that ensures data integrity and security.
# * Implement data backups and regular software updates to prevent downtime.
#
# ### 4. Testing and Quality Assurance
#
# #### 4.1 Automated Testing
# * Write comprehensive automated tests using tools like Jest or Pytest to ensure the system functions as expected.
# * Perform unit testing, integration testing, and UI testing to cover various scenarios.
#
# #### 4.2 Manual Testing
# * Conduct thorough manual testing to identify bugs and edge cases that may have been missed by automation.
# * Test on different devices, browsers, and networks to ensure compatibility.
#
# ### 5. Deployment and Maintenance
#
# #### 5.1 Continuous Integration and Deployment (CI/CD)
# * Set up a CI/CD pipeline using tools like Jenkins or CircleCI to automate testing, building, and deployment.
# * Ensure continuous monitoring of the system for errors and issues.
#
# #### 5.2 Regular Updates
# * Schedule regular software updates to ensure the system remains secure and feature-rich.
# * Implement a change management process to minimize downtime during updates.
#
# ### Conclusion
#
# By following these guidelines, you'll create a robust, user-friendly learning platform that prioritizes performance, security, and scalability.
# Time taken: 112.617s
# {'model': 'llama3.2:latest', 'prompt': 'Your last response improved the requirements, but now optimize for clarity.\n\n## **Step 3: Final Optimization**\n- Ensure **concise but complete** descriptions.\n- **Remove redundant words** while keeping **technical depth**.\n- Maintain **structured bullet points**.\n- **Do not include unnecessary explanations or conclusions**.\n\n### **Previous Refined Response:**\n## Structured Requirement Analysis for Personalized Learning System\n\n### Overview\nThe following is a comprehensive requirement analysis for the development of a personalized learning system designed to cater to diverse user needs, promoting academic success and lifelong learning.\n\n### 1. Functional Requirements\n\n#### 1.1 User Registration and Login\n* Users will be able to register with their username, email address, and password.\n* The system will ensure that each user has a unique username and email address, preventing duplicate accounts.\n* Users can log in using their credentials or opt for biometric login options (optional).\n\n#### 1.2 Course Management\n* Users will have access to a comprehensive catalog of courses, including descriptions, prerequisites, and course materials.\n* The system will display relevant course suggestions based on user interests and skill levels.\n\n#### 1.3 Learning Paths\n* Users can create personalized learning paths tailored to their goals, interests, and skills.\n* Each learning path will include a list of recommended courses, readings, and assignments.\n\n#### 1.4 Adaptive Assessment\n* The system will conduct regular assessments to evaluate user progress and understanding.\n* Assessments will be adaptive, adjusting difficulty levels based on user performance.\n\n#### 1.5 Personalized Feedback\n* Users will receive personalized feedback on their performance, including explanations of correct answers and suggested improvements.\n* Feedback will be provided in a clear, concise manner, ensuring users understand the material.\n\n### 2. Non-Functional Requirements\n\n#### 2.1 Performance\n* The system must respond to user interactions within 2 seconds.\n* Average page load time should be less than 3 seconds.\n\n#### 2.2 Security\n* User data will be encrypted using industry-standard encryption protocols (e.g., AES).\n* Passwords will be hashed and stored securely, requiring users to change passwords every 90 days.\n\n#### 2.3 Usability\n* The system must be accessible on a range of devices, including desktops, laptops, tablets, and mobile phones.\n* Navigation should be intuitive, with clear typography and color schemes that reduce visual stress.\n\n### 3. Technical Requirements\n\n#### 3.1 Frontend Framework\n* Utilize a popular frontend framework (e.g., React, Angular) to ensure responsiveness and maintainability.\n* Ensure compatibility across various browsers and devices.\n\n#### 3.2 Backend Platform\n* Choose a robust backend platform (e.g., Node.js, Django) that supports scalability and high traffic.\n* Integrate with cloud services for storage and analytics.\n\n#### 3.3 Database Management\n* Select a reliable database management system (e.g., MySQL, PostgreSQL) that ensures data integrity and security.\n* Implement data backups and regular software updates to prevent downtime.\n\n### 4. Testing and Quality Assurance\n\n#### 4.1 Automated Testing\n* Write comprehensive automated tests using tools like Jest or Pytest to ensure the system functions as expected.\n* Perform unit testing, integration testing, and UI testing to cover various scenarios.\n\n#### 4.2 Manual Testing\n* Conduct thorough manual testing to identify bugs and edge cases that may have been missed by automation.\n* Test on different devices, browsers, and networks to ensure compatibility.\n\n### 5. Deployment and Maintenance\n\n#### 5.1 Continuous Integration and Deployment (CI/CD)\n* Set up a CI/CD pipeline using tools like Jenkins or CircleCI to automate testing, building, and deployment.\n* Ensure continuou ...
#
# Final Optimized Response:
#  !!ERROR!! Request failed! You need to adjust prompt-eng/config with URL(http://localhost:11434/api/generate)
# Time taken: -1s

# %% [markdown]
# # Over-Generated Content →
# AI expanded beyond required Functional & Non-Functional Requirements (e.g., added Technical, Testing, and Deployment details).
#  Redundant Details → AI repeated key points (e.g., Plan Generation & Learning Resource Management in different sections).
#  More than 2 Functional & 2 Non-Functional Requirements → The AI ignored the limit set in the prompt.
#  Execution Time Increased (93.457s) → Output is longer than necessary."""
